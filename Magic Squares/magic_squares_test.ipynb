# %%
import magicSquares

# %%
for i in range(4):
    magicSquares.magicSquares()
    print('--------------------------')
# Out:
# Enter a magic square of n by n size as n rows and n
# columns of values separated by spaces - enter 0 for
# blank spaces and the given number for preset spaces.
# Press Enter after entering the nth row for solution.
# Size of puzzle: 4
# Is the magic square normal? (y/n): y
# 0 16 0 5
# 0 4 9 6
# 0 0 0 11
# 7 0 0 0
#
# [10, 16, 3, 5]
# [15, 4, 9, 6]
# [2, 13, 8, 11]
# [7, 1, 14, 12]
#
# Statistics
#   - status          : OPTIMAL
#   - conflicts       : 0
#   - branches        : 0
#   - wall time       : 0.001137 s
#   - solutions found : 1
# --------------------------
# Enter a magic square of n by n size as n rows and n
# columns of values separated by spaces - enter 0 for
# blank spaces and the given number for preset spaces.
# Press Enter after entering the nth row for solution.
# Size of puzzle: 3
# Is the magic square normal? (y/n): y
# 0 0 2
# 0 5 9
# 0 3 0
#
# [6, 7, 2]
# [1, 5, 9]
# [8, 3, 4]
#
# Statistics
#   - status          : OPTIMAL
#   - conflicts       : 0
# ...
